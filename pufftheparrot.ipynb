# %%
6/27/2022 - DISCORD UPDATES

>> IMPROVED THE INFORMATION SECTION

>> PLANNING -- Creating the DYNO or Mee6 Bot into the Server.

>> NEED --- ADMIN PERMISSION TO ADD WICK BOT TO THE SERVER.


>> NFT PROGRAMMING PART 1 --

PUFF THE PARRT NFT TRAITS COUNT
// Description: Describes the number of traits that's within the Puff the Parrot NFT collection. This will help the development team by defining the metadata and minting in the future steps. 

> OBJECTS (11); 
> BEAKS (8);
> EYES (12);
> HEADWEAR (9);
> CLOTHING (10);
> BODY_COLOR (7);
> WINGS (21);
> BACKGROUND (10);


// RARITY MATH 
Objects = 11 x 8 = 88
88 + 12 = 100
12 can be divisible to = 6, 3, 3
88 + 6 + 3 + 3 = 100


Beaks = 100 / 8 = 12.5
13 x 7 = 91
91 + x = 100
x= 100 - 91 
x = 9

[13,13,13,13,13,13,13,9]


Eyes = 100 / 12 = 8.3
8 x 11 = 88
88 + x = 100
x = 100 - 88
x = 22

[22,8,8,8,8,8,8,8,8,8,8,8]

Headwear = 100 / 9 = 11.1
12 x 8 = 96

96 + x = 100

x = 100 - 96 = 4
x = 4 (rare crown)

[12, 12, 12, 12, 12, 12, 12, 4, 12]


Clothing = 100 / 10 = 10 
[10, 10, 10, 10, 10, 10, 10, 10, 10, 10]

Body Color = 100/ 7 
15 x 6 = 90

90 + x = 100
x = 100 - 90
x = 10


Wings = 100 / 21 = 
4 x 20 = 80

80 + x = 100
x = 100 - 80
x = 20

[4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 20]

# %% [markdown]
# ASSIGNING RAIRITY
# Description: We are creating a rarity with the traits that we have found. Each of the traits have a weight up to 100. Because of this, you have to make sure that the numbers for the weight rarity always equals
# up to 100. For example, 21 wings traits will all need a number of rarity that has a weight total of 100.
#
#
# # Each image is made up a series of traits
# # The weightings for each trait drive the rarity and add up to 100%
# # The wing colors will be separated by [COLOR NAME, ABC]. IE.
# # A = Joint Wing, B = Bong Wing, C = Blunt Wing
#
# objects = ["Headphones", "Joint Wing A", "Puff Glasses", "Bitcoin Chain", "Ethereum Chain", "Purple Bandana", "Puff 2024 Flag WING B", "Blunt WING C", "Bong WING B", "Pipe WING B", "Monocle" ]
# objects_weights = [11, 11, 11, 11, 11, 11, 11, 11, 6, 3, 3]
#
# beaks = ["BEAK #1", "BEAK #2", "BEAK #3", "BEAK #4", "BEAK #5", "BEAK #6", "BEAK #7", "BEAK #8"]
# beaks_weights = [13, 13, 13, 13, 13, 13, 13, 9]
#
# eyes = ["EYES #1", "EYES #2", "EYES #3", "EYES #4","EYES #5", "EYES #6", "EYES #7", "EYES #8", "EYES #9", "EYES #10", "EYES #11", "EYES #12"]
# eyes_weights = [22, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]
#
# headwear = ["Backwards Cap", "Winter Hat", "Orange Bandanna", "Make America Puff Again Hat", "Propeller Hat", "Top Hat", "Mohawk", "Gold Crown(Rare)", "Pirate Hat"]
# headwear_weights = [12, 12, 12, 12, 12, 12, 12, 4, 12]
#
# clothing = ["Patrick Jersey", "Bruins #4 Jersey", "Red Sox Jersey", "Orange Hawaiian Jersey", "Business Suit", "Tie Dye Hoodie", "Blue Hoodie", "Make America Puff Again Hoodie", "Puff You! Hoodie", "Celtics #33 Jersey"]
# clothing_weights = [10, 10, 10, 10, 10, 10, 10, 10, 10, 10]
#
# body_color =  ["COLOR #1", "COLOR #2", "COLOR #3", "COLOR #4", "COLOR #5", "COLOR #7"]
# body_color_weights = [15, 15, 15, 15, 15, 15, 10]
#
# wings = ["BLUE A", "BLUE B", "BLUE C", "PINK A", "PINK B", "PINK C", "GOLD A", "GOLD B", "GOLD C", "GREEN A", "GREEN B", "GREEN C", "YELLOW A", "YELLOW B", "YELLOW C", "RAINBOW A", "RAINBOW B", "RAINBOW C", "SILVER A", "SILVER B", "SILVER C"]
# wings_weight = [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 20]
#
# background = ["BACKGROUND #1", "BACKGROUND #2", "BACKGROUND #3", "BACKGROUND #4", "BACKGROUND #5", "BACKGROUND #6", "BACKGROUND #8", "BACKGROUND #9", "BACKGROUND #10"]
# background_weight = [10, 10, 10, 10, 10, 10, 10, 10, 10, 10]

# %% [markdown]
# STEP 3 - CLASSIFY THE TRAITS
#
# >> FIND PNG VERSION OF EACH PDF FILE
#
#
# // TRAIT 1 - OBJECTS //
#
# objects_files = {
#     "Headphones": "objects1",
#     "Joint Wing A": "objects2",
#     "Puff Glasses": "objects3",
#     "Bitcoin Chain": "objects4",
#     "Ethereum Chain": "objects5",
#     "Purple Bandana": "objects6",
#     "Puff 2024 Flag WING B": "objects7",
#     "Blunt WING C": "objects8",
#     "Bong WING B": "objects9",
#     "Pipe WING B": "objects10",
#     "Monocle": "objects11"
# }
#
# // TRAIT 2 - BEAKS //
#
# beaks_files = {
#   "BEAK #1": "beak1",
#   "BEAK #2": "beak2",
#   "BEAK #3": "beak3",
#   "BEAK #4": "beak4",
#   "BEAK #5": "beak5",
#   "BEAK #6": "beak6",
#   "BEAK #7": "beak7",
#   "BEAK #8": "beak8"
# }
#
#
# // TRAIT 3 - EYES //
# eyes_files = {
#     "EYES #1": "eyes1",
#     "EYES #2": "eyes2",
#     "EYES #3": "eyes3",
#     "EYES #4": "eyes4",
#     "EYES #5": "eyes5",
#     "EYES #6": "eyes6",
#     "EYES #7": "eyes7",
#     "EYES #8": "eyes8",
#     "EYES #9": "eyes9",
#     "EYES #10": "eyes10",
#     "EYES #11": "eyes11",
#     "EYES #12": "eyes12"
# }
#
#
# // TRAIT 4 - HEADWEAR //
#
# headwear_files = {
#     "Backwards Cap": "headwear1",
#     "Winter Hat": "headwear2",
#     "Orange Bandana": "headwear3",
#     "Make America Puff Again Hat": "headwear4",
#     "Propeller Hat": "headwear5",
#     "Top Hat": "headwear6",
#     "Mohawk": "headwear7",
#     "Gold Crown(Rare)": "headwear8",
#     "Pirate Hat": "headwear9"
#
# }
#
#
# // TRAIT 5 - CLOTHING //
#
# clothing_files = {
#     "Patrick Jersey": "clothing1",
#     "Bruins #4 Jersey": "clothing2",
#     "Red Sox Jersey": "clothing3",
#     "Orange Hawaiian Jersey": "clothing4",
#     "Business Suit": "clothing5",
#     "Tie Dye Hoodie": "clothing6",
#     "Blue Hoodie": "clothing7",
#     "Make America Puff Again Hoodie": "clothing8",
#     "Puff You! Hoodie": "clothing9",
#     "Celtics #33 Jersey": "clothing10"
#
#
# }
#
#
#
# // TRAIT 6 - Body Colors //
#
# body_color_files = {
#     "COLOR #1": "bodycolor1",
#     "COLOR #2": "bodycolor2",
#     "COLOR #3": "bodycolor3",
#     "COLOR #4": "bodycolor4",
#     "COLOR #5": "bodycolor5",
#     "COLOR #6": "bodycolor6",
#     "COLOR #7": "bodycolor7"
# }
#
# // TRAIT 7 - Wings //
#
# wings_files = {
# "BLUE A": "wings1",
# "BLUE B": "wings2",
# "BLUE C": "wings3",
# "PINK A": "wings4",
# "PINK B": "wings5",
# "PINK C": "wings6",
# "GOLD A": "wings7",
# "GOLD B": "wings8",
# "GOLD C": "wings9",
# "GREEN A": "wings10",
# "GREEN B": "wings11",
# "GREEN C": "wings12",
# "YELLOW A": "wings13",
# "YELLOW B": "wings14",
# "YELLOW C": "wings15",
# "RAINBOW A": "wings16",
# "RAINBOW B": "wings17",
# "RAINBOW C": "wings18",
# "SILVER A": "wings19",
# "SILVER B": "wings20",
# "SILVER C": "wings21"
#
#
# }
#
# // TRAIT 8 - BACKGROUND //
#
# background_files = {
#     "BACKGROUND #1": "background1",
#     "BACKGROUND #2": "background2",
#     "BACKGROUND #3": "background3",
#     "BACKGROUND #4": "background4 "                                                     ,                                                                     , "BACKGROUND #5", "BACKGROUND #6", "BACKGROUND #8", "BACKGROUND #9", "BACKGROUND #10"]
# }
